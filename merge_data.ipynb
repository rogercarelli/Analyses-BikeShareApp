# %% [markdown]
# # Data cleanig
# ### Bike rides for the past 12 months

# %%
import pandas as pd
import os
import sqlite3
import geopy.distance

# %% [markdown]
# ### Merge raw data
#
# Merge all the tables into a single dataframe
#
# Each table corresponds to a month of the past year

# %%
# ride_data is the folder where all the data is stored
cd = os.getcwd()
directory = "{}\\ride_data".format(cd)

# %%
# Creates the DF
df = pd.read_csv(directory+"\\divvy_trip (1).csv")

# %%
# Loop through the last 11 months of Ride Data and append to the existing df
for file in os.listdir(directory):
    if not directory+"\\divvy_trip (1).csv" == directory+"\\"+file:
        df = df.append(pd.DataFrame(pd.read_csv(directory+"\\"+file)), ignore_index=True)
print('done')
# Out:
# done

# %%
df.dropna(inplace=True)

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4641395 entries, 0 to 5723481
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: float64(4), object(9)
# memory usage: 3.0 GB

# %%
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  47EC0A7F82E65D52   classic_bike  2022-03-21 13:45:01  2022-03-21 13:51:18
# 1  8494861979B0F477  electric_bike  2022-03-16 09:37:16  2022-03-16 09:43:34
# 2  EFE527AF80B66109   classic_bike  2022-03-23 19:52:02  2022-03-23 19:54:48
# 3  9F446FD9DEE3F389   classic_bike  2022-03-01 19:12:26  2022-03-01 19:22:14
# 4  431128AD9AFFEDC0   classic_bike  2022-03-21 18:37:01  2022-03-21 19:19:11
#
#                    start_station_name start_station_id  \
# 0              Wabash Ave & Wacker Pl     TA1307000131
# 1               Michigan Ave & Oak St            13042
# 2               Broadway & Berwyn Ave            13109
# 3              Wabash Ave & Wacker Pl     TA1307000131
# 4  DuSable Lake Shore Dr & North Blvd           LF-005
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0              Kingsbury St & Kinzie St   KA1503000043  41.886875 -87.626030
# 1  Orleans St & Chestnut St (NEXT Apts)            620  41.900998 -87.623752
# 2                  Broadway & Ridge Ave          15578  41.978353 -87.659753
# 3            Franklin St & Jackson Blvd   TA1305000025  41.886875 -87.626030
# 4              Loomis St & Jackson Blvd          13206  41.911722 -87.626804
#
#      end_lat    end_lng member_casual
# 0  41.889177 -87.638506        member
# 1  41.898203 -87.637536        member
# 2  41.984045 -87.660274        member
# 3  41.877708 -87.635321        member
# 4  41.877945 -87.662007        member

# %% [markdown]
# ### Date convertion
# * Converting dates into seconds
# * New column: weekday >> 0 is Monday, 6 is Sunday
# * New column: duration_ns >> end - start in nanoseconds
# * Remove ride durations < 1min and > 24hrs

# %%
df.loc[ : , "started_at"] = pd.to_datetime(df.loc[ : , "started_at"], yearfirst=True)
df.loc[ : , "ended_at"] = pd.to_datetime(df.loc[ : , "ended_at"], yearfirst=True)
df['weekday'] = df.started_at.dt.dayofweek

# %%
df['duration'] = (df['ended_at'] - df['started_at']).dt.total_seconds()

# %%
df = df[df['duration'] >= 60]        # 1 minute
df = df[df['duration'] <= 24*60*60]  # 24 hours

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4579009 entries, 0 to 5723481
# Data columns (total 15 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          datetime64[ns]
#  3   ended_at            datetime64[ns]
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
#  13  weekday             int64
#  14  duration            float64
# dtypes: datetime64[ns](2), float64(5), int64(1), object(7)
# memory usage: 2.4 GB

# %%
df.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  47EC0A7F82E65D52   classic_bike 2022-03-21 13:45:01 2022-03-21 13:51:18
# 1  8494861979B0F477  electric_bike 2022-03-16 09:37:16 2022-03-16 09:43:34
# 2  EFE527AF80B66109   classic_bike 2022-03-23 19:52:02 2022-03-23 19:54:48
# 3  9F446FD9DEE3F389   classic_bike 2022-03-01 19:12:26 2022-03-01 19:22:14
# 4  431128AD9AFFEDC0   classic_bike 2022-03-21 18:37:01 2022-03-21 19:19:11
#
#                    start_station_name start_station_id  \
# 0              Wabash Ave & Wacker Pl     TA1307000131
# 1               Michigan Ave & Oak St            13042
# 2               Broadway & Berwyn Ave            13109
# 3              Wabash Ave & Wacker Pl     TA1307000131
# 4  DuSable Lake Shore Dr & North Blvd           LF-005
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0              Kingsbury St & Kinzie St   KA1503000043  41.886875 -87.626030
# 1  Orleans St & Chestnut St (NEXT Apts)            620  41.900998 -87.623752
# 2                  Broadway & Ridge Ave          15578  41.978353 -87.659753
# 3            Franklin St & Jackson Blvd   TA1305000025  41.886875 -87.626030
# 4              Loomis St & Jackson Blvd          13206  41.911722 -87.626804
#
#      end_lat    end_lng member_casual  weekday  duration
# 0  41.889177 -87.638506        member        0     377.0
# 1  41.898203 -87.637536        member        2     378.0
# 2  41.984045 -87.660274        member        2     166.0
# 3  41.877708 -87.635321        member        1     588.0
# 4  41.877945 -87.662007        member        0    2530.0

# %% [markdown]
# ### Get unique stations
#
# Filter only unique stations

# %%
all_stations = pd.DataFrame(columns=['station_name', 'lat', 'lng'])

# %%
started_stations = df[['start_station_name', 'start_lat', 'start_lng']]
started_stations.rename(inplace=True, columns={'start_station_name': 'station_name', 
                                               'start_lat': 'lat', 'start_lng': 'lng'} )
# Out:
# E:\Anaconda\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
ended_stations = df[['end_station_name', 'end_lat', 'end_lng']]
ended_stations.rename(inplace=True, columns={'end_station_name': 'station_name', 
                                             'end_lat': 'lat', 'end_lng': 'lng'} )

# %%
all_stations = all_stations.append(started_stations)
all_stations = all_stations.append(ended_stations)

# %%
all_stations.drop_duplicates(inplace=True, subset='station_name')

# %%
all_stations
# Out:
#                                  station_name        lat        lng
# 0                      Wabash Ave & Wacker Pl  41.886875 -87.626030
# 1                       Michigan Ave & Oak St  41.900998 -87.623752
# 2                       Broadway & Berwyn Ave  41.978353 -87.659753
# 4          DuSable Lake Shore Dr & North Blvd  41.911722 -87.626804
# 5                   Bissell St & Armitage Ave  41.918018 -87.652182
# ...                                       ...        ...        ...
# 2995292                Indiana Ave & 133rd St  41.650000 -87.620000
# 4177511                                   351  41.930000 -87.780000
# 4906316                       WEST CHI-WATSON  41.894702 -87.730884
# 4954339  DIVVY CASSETTE REPAIR MOBILE STATION  41.880958 -87.616743
# 2412049           Whipple St & Irving Park Rd  41.950000 -87.700000
#
# [859 rows x 3 columns]

# %% [markdown]
# ### Stations' distance
# Calculate distance using geografical coordanates

# %%
# Calculate the distance between stations

def station_dist(list_coord):
    # list_coord: start lat, start lng, end lat, end lng
    
    # To float
    coord = [float(coord) for coord in list_coord]
    
    # start and end coord must be a tuple of (lat, long)
    dist = geopy.distance.distance((coord[0], coord[1]), (coord[2], coord[3])).m
    return int(round(dist, 0))

# %% [raw]
# # As the calculation takes too much time, I saved the results to a csv to reuse it without waiting.
#
# # Converts coord to string and combine them into one thing
# stations_coord = df['start_lat'].astype(str) + " " + df['start_lng'].astype(str) + " " + df['end_lat'].astype(str) + " " + df['end_lng'].astype(str)
#
# # Iterate each coord combination and calculate the distance between stations
# list_dist = []
# for i, coord in enumerate(stations_coord):
#     if i%100000 == 0: print(i/len(stations_coord)*100, "%")
#     list_dist.append(station_dist(coord.split(" ")))
#
# print("Done")
# # Export the results to a csv file
# pd.DataFrame(list_dist).to_csv("stations_distance.csv", index=False)

# %%
df['stations_distance_m'] = pd.read_csv("stations_distance.csv", header=None)

# %% [markdown]
# ## Dataframe creation steps-by-step
# #### We are going to separate this data into mulitple tables
#
# * rides
# * ride_duration
# * stations

# %%
df_rides = df[['ride_id', 'rideable_type', 'start_station_name',
               'end_station_name', 'stations_distance_m', 'member_casual']]
df_rides
# Out:
#                   ride_id  rideable_type                  start_station_name  \
# 0        47EC0A7F82E65D52   classic_bike              Wabash Ave & Wacker Pl
# 1        8494861979B0F477  electric_bike               Michigan Ave & Oak St
# 2        EFE527AF80B66109   classic_bike               Broadway & Berwyn Ave
# 3        9F446FD9DEE3F389   classic_bike              Wabash Ave & Wacker Pl
# 4        431128AD9AFFEDC0   classic_bike  DuSable Lake Shore Dr & North Blvd
# ...                   ...            ...                                 ...
# 5723378  1B88F66E86C094DB   classic_bike               Clark St & Leland Ave
# 5723400  E73A038DA647AAFF    docked_bike               Michigan Ave & Oak St
# 5723421  4AD181F39CCB99ED   classic_bike            Kingsbury St & Kinzie St
# 5723462  D6AE7BEA1D494E4B   classic_bike               Michigan Ave & Oak St
# 5723481  84E1F8369EEE874E   classic_bike           Desplaines St & Kinzie St
#
#                              end_station_name  stations_distance_m  \
# 0                    Kingsbury St & Kinzie St                  0.0
# 1        Orleans St & Chestnut St (NEXT Apts)               1067.0
# 2                        Broadway & Ridge Ave               1185.0
# 3                  Franklin St & Jackson Blvd                634.0
# 4                    Loomis St & Jackson Blvd               1277.0
# ...                                       ...                  ...
# 5723378                 Clark St & Leland Ave                  NaN
# 5723400                 Michigan Ave & Oak St                  NaN
# 5723421             Desplaines St & Kinzie St                  NaN
# 5723462                 Michigan Ave & Oak St                  NaN
# 5723481                 Michigan Ave & Oak St                  NaN
#
#         member_casual
# 0              member
# 1              member
# 2              member
# 3              member
# 4              member
# ...               ...
# 5723378        member
# 5723400        casual
# 5723421        member
# 5723462        member
# 5723481        member
#
# [4579009 rows x 6 columns]

# %%
df_ride_duration = df[['ride_id', 'member_casual', 'started_at', 'ended_at', 'duration', 'weekday']]
df_ride_duration
# Out:
#                   ride_id member_casual          started_at  \
# 0        47EC0A7F82E65D52        member 2022-03-21 13:45:01
# 1        8494861979B0F477        member 2022-03-16 09:37:16
# 2        EFE527AF80B66109        member 2022-03-23 19:52:02
# 3        9F446FD9DEE3F389        member 2022-03-01 19:12:26
# 4        431128AD9AFFEDC0        member 2022-03-21 18:37:01
# ...                   ...           ...                 ...
# 5723378  1B88F66E86C094DB        member 2021-07-18 11:51:19
# 5723400  E73A038DA647AAFF        casual 2021-07-23 11:30:06
# 5723421  4AD181F39CCB99ED        member 2021-07-12 17:42:02
# 5723462  D6AE7BEA1D494E4B        member 2021-07-17 17:01:24
# 5723481  84E1F8369EEE874E        member 2021-07-30 04:54:54
#
#                    ended_at  duration  weekday
# 0       2022-03-21 13:51:18     377.0        0
# 1       2022-03-16 09:43:34     378.0        2
# 2       2022-03-23 19:54:48     166.0        2
# 3       2022-03-01 19:22:14     588.0        1
# 4       2022-03-21 19:19:11    2530.0        0
# ...                     ...       ...      ...
# 5723378 2021-07-18 12:36:24    2705.0        6
# 5723400 2021-07-23 12:37:25    4039.0        4
# 5723421 2021-07-12 17:45:44     222.0        0
# 5723462 2021-07-17 17:38:14    2210.0        5
# 5723481 2021-07-30 05:06:41     707.0        4
#
# [4579009 rows x 6 columns]

# %%
df_stations = all_stations
df_stations
# Out:
#                                  station_name        lat        lng
# 0                      Wabash Ave & Wacker Pl  41.886875 -87.626030
# 1                       Michigan Ave & Oak St  41.900998 -87.623752
# 2                       Broadway & Berwyn Ave  41.978353 -87.659753
# 4          DuSable Lake Shore Dr & North Blvd  41.911722 -87.626804
# 5                   Bissell St & Armitage Ave  41.918018 -87.652182
# ...                                       ...        ...        ...
# 2995292                Indiana Ave & 133rd St  41.650000 -87.620000
# 4177511                                   351  41.930000 -87.780000
# 4906316                       WEST CHI-WATSON  41.894702 -87.730884
# 4954339  DIVVY CASSETTE REPAIR MOBILE STATION  41.880958 -87.616743
# 2412049           Whipple St & Irving Park Rd  41.950000 -87.700000
#
# [859 rows x 3 columns]

# %% [markdown]
# ### Export to a SQL database

# %%
con = sqlite3.connect('divy.db')

# %%
# Save the data
df_rides.to_sql("Rides", index=False, con=con)
df_ride_duration.to_sql("Rides_duration", index=False, con=con)
df_stations.to_sql("Stations", index=False, con=con)
